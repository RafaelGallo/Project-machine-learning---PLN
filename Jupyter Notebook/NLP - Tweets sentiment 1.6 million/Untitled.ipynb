# %%
#!pip install datapackage

# %%
from datapackage import Package

package = Package('https://datahub.io/core/covid-19/datapackage.json')

# %%
print(package.resource_names)
# Out:
# ['validation_report', 'countries-aggregated_csv', 'key-countries-pivoted_csv', 'reference_csv', 'time-series-19-covid-combined_csv', 'us_confirmed_csv', 'us_deaths_csv', 'us_simplified_csv', 'worldwide-aggregate_csv', 'countries-aggregated_json', 'key-countries-pivoted_json', 'reference_json', 'time-series-19-covid-combined_json', 'us_confirmed_json', 'us_deaths_json', 'us_simplified_json', 'worldwide-aggregate_json', 'covid-19_zip', 'countries-aggregated_csv_preview', 'reference_csv_preview', 'time-series-19-covid-combined_csv_preview', 'us_confirmed_csv_preview', 'us_deaths_csv_preview', 'us_simplified_csv_preview', 'countries-aggregated', 'key-countries-pivoted', 'reference', 'time-series-19-covid-combined', 'us_confirmed', 'us_deaths', 'us_simplified', 'worldwide-aggregate']

# %%
for resource in package.resources:
    if resource.descriptor['datahub']['type'] == 'derived/csv':
        print(resource.read())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [[datetime.date(2020, 1, 22), 548, 1, 0, 0, 0, 0, 0, 0], [datetime.date(2020, 1, 23), 643, 1, 0, 0, 0, 0, 0, 0], [datetime.date(2020, 1, 24), 920, 2, 0, 0, 2, 0, 0, 0], [datetime.date(2020, 1, 25), 1406, 2, 0, 0, 3, 0, 0, 0], [datetime.date(2020, 1, 26), 2075, 5, 0, 0, 3, 0, 0, 0], [datetime.date(2020, 1, 27), 2877, 5, 0, 0, 3, 1, 0, 0], [datetime.date(2020, 1, 28), 5509, 5, 0, 0, 4, 4, 0, 0], [datetime.date(2020, 1, 29), 6087, 6, 0, 0, 5, 4, 0, 0], [datetime.date(2020, 1, 30), 8141, 6, 0, 0, 5, 4, 0, 0], [datetime.date(2020, 1, 31), 9802, 8, 2, 2, 5, 5, 0, 0], [datetime.date(2020, 2, 1), 11891, 8, 2, 2, 6, 8, 1, 0], [datetime.date(2020, 2, 2), 16630, 8, 2, 2, 6, 10, 1, 0], [datetime.date(2020, 2, 3), 19716, 11, 8, 2, 6, 12, 1, 0], [datetime.date(2020, 2, 4), 23707, 11, 8, 2, 6, 12, 1, 0], [datetime.date(2020, 2, 5), 27440, 11, 9, 2, 6, 12, 1, 0], [datetime.date(2020, 2, 6), 30587, 12, 9, 2, 6, 12, 1, 0], [datetime.date(2020, 2, 7), 34110, 12, 9, 3, 6, 13, 1, 0], [datetime.date(2020, 2, 8), 36814, 12, 13, 3, 11, 13, 1, 0], [datetime.date(2020, 2, 9), 39829, 12, 14, 3, 11, 14, 2, 0], [datetime.date(2020, 2, 10), 42354, 12, 14, 3, 11, 14, 2, 0], [datetime.date(2020, 2, 11), 44386, 13, 15, 3, 11, 16, 2, 0], [datetime.date(2020, 2, 12), 44759, 13, 16, 3, 11, 16, 2, 0], [datetime.date(2020, 2, 13), 59895, 14, 17, 3, 11, 16, 2, 0], [datetime.date(2020, 2, 14), 66358, 14, 18, 3, 11, 16, 2, 0], [datetime.date(2020, 2, 15), 68413, 14, 18, 3, 12, 16, 2, 0], [datetime.date(2020, 2, 16), 70513, 14, 18, 3, 12, 16, 2, 0], [datetime.date(2020, 2, 17), 72434, 14, 19, 3, 12, 16, 2, 0], [datetime.date(2020, 2, 18), 74211, 14, 19, 3, 12, 16, 2, 0], [datetime.date(2020, 2, 19), 74619, 14, 20, 3, 12, 16, 2, 2], [datetime.date(2020, 2, 20), 75077, 14, 22, 3, 12, 16, 2, 5], [datetime.date(2020, 2, 21), 75550, 16, 23, 20, 12, 16, 2, 18], [datetime.date(2020, 2, 22), 77001, 16, 23, 62, 12, 16, 2, 28], [datetime.date(2020, 2, 23), 77022, 16, 28, 155, 12, 16, 2, 43], [datetime.date(2020, 2, 24), 77241, 16, 30, 229, 12, 16, 2, 61], [datetime.date(2020, 2, 25), 77754, 16, 34, 322, 14, 17, 6, 95], [datetime.date(2020, 2, 26), 78166, 16, 37, 453, 18, 27, 13, 139], [datetime.date(2020, 2, 27), 78600, 17, 44, 655, 38, 46, 15, 245], [datetime.date(2020, 2, 28), 78928, 17, 56, 888, 57, 48, 32, 388], [datetime.date(2020, 2, 29), 79356, 25, 61, 1128, 100, 79, 45, 593], [datetime.date(2020, 3, 1), 79932, 32, 94, 1694, 130, 130, 84, 978], [datetime.date(2020, 3, 2), 80136, 55, 134, 2036, 191, 159, 120, 1501], [datetime.date(2020, 3, 3), 80261, 74, 189, 2502, 212, 196, 165, 2336], [datetime.date(2020, 3, 4), 80386, 107, 246, 3089, 288, 262, 222, 2922], [datetime.date(2020, 3, 5), 80537, 184, 295, 3858, 426, 482, 259, 3513], [datetime.date(2020, 3, 6), 80690, 237, 374, 4636, 616, 670, 400, 4747], [datetime.date(2020, 3, 7), 80770, 403, 429, 5883, 948, 799, 500, 5823], [datetime.date(2020, 3, 8), 80823, 519, 483, 7375, 1125, 1040, 673, 6566], [datetime.date(2020, 3, 9), 80860, 594, 630, 9172, 1411, 1176, 1073, 7161], [datetime.date(2020, 3, 10), 80887, 782, 889, 10149, 1783, 1457, 1695, 8042], [datetime.date(2020, 3, 11), 80921, 1147, 1301, 12462, 2293, 1908, 2277, 9000], [datetime.date(2020, 3, 12), 80932, 1586, 1790, 15113, 2293, 2078, 2277, 10075], [datetime.date(2020, 3, 13), 80945, 2219, 2270, 17660, 3681, 3675, 5232, 11364], [datetime.date(2020, 3, 14), 80977, 2978, 2634, 21157, 4496, 4585, 6391, 12729], [datetime.date(2020, 3, 15), 81003, 3212, 3077, 24747, 4532, 5795, 7798, 13938], [datetime.date(2020, 3, 16), 81033, 4679, 3692, 27980, 6683, 7272, 9942, 14991], [datetime.date(2020, 3, 17), 81058, 6512, 4462, 31506, 7715, 9257, 11748, 16169], [datetime.date(2020, 3, 18), 81102, 9169, 5468, 35713, 9124, 12327, 13910, 17361], [datetime.date(2020, 3, 19), 81156, 13663, 6534, 41035, 10970, 15320, 17963, 18407], [datetime.date(2020, 3, 20), 81250, 20030, 7792, 47021, 12758, 19848, 20410, 19644], [datetime.date(2020, 3, 21), 81305, 26025, 9007, 53578, 14463, 22213, 2 ...
# [[4, 'AF', 'AFG', 4, None, None, None, 'Afghanistan', Decimal('33.93911'), Decimal('67.709953'), 'Afghanistan', 38928341], [8, 'AL', 'ALB', 8, None, None, None, 'Albania', Decimal('41.1533'), Decimal('20.1683'), 'Albania', 2877800], [12, 'DZ', 'DZA', 12, None, None, None, 'Algeria', Decimal('28.0339'), Decimal('1.6596'), 'Algeria', 43851043], [20, 'AD', 'AND', 20, None, None, None, 'Andorra', Decimal('42.5063'), Decimal('1.5218'), 'Andorra', 77265], [24, 'AO', 'AGO', 24, None, None, None, 'Angola', Decimal('-11.2027'), Decimal('17.8739'), 'Angola', 32866268], [28, 'AG', 'ATG', 28, None, None, None, 'Antigua and Barbuda', Decimal('17.0608'), Decimal('-61.7964'), 'Antigua and Barbuda', 97928], [32, 'AR', 'ARG', 32, None, None, None, 'Argentina', Decimal('-38.4161'), Decimal('-63.6167'), 'Argentina', 45195777], [51, 'AM', 'ARM', 51, None, None, None, 'Armenia', Decimal('40.0691'), Decimal('45.0382'), 'Armenia', 2963234], [40, 'AT', 'AUT', 40, None, None, None, 'Austria', Decimal('47.5162'), Decimal('14.5501'), 'Austria', 9006400], [31, 'AZ', 'AZE', 31, None, None, None, 'Azerbaijan', Decimal('40.1431'), Decimal('47.5769'), 'Azerbaijan', 10139175], [44, 'BS', 'BHS', 44, None, None, None, 'Bahamas', Decimal('25.025885'), Decimal('-78.035889'), 'Bahamas', 393248], [48, 'BH', 'BHR', 48, None, None, None, 'Bahrain', Decimal('26.0275'), Decimal('50.55'), 'Bahrain', 1701583], [50, 'BD', 'BGD', 50, None, None, None, 'Bangladesh', Decimal('23.685'), Decimal('90.3563'), 'Bangladesh', 164689383], [52, 'BB', 'BRB', 52, None, None, None, 'Barbados', Decimal('13.1939'), Decimal('-59.5432'), 'Barbados', 287371], [112, 'BY', 'BLR', 112, None, None, None, 'Belarus', Decimal('53.7098'), Decimal('27.9534'), 'Belarus', 9449321], [56, 'BE', 'BEL', 56, None, None, None, 'Belgium', Decimal('50.8333'), Decimal('4.469936'), 'Belgium', 11589616], [5601, 'BE', 'BEL', 56, None, None, 'Antwerp', 'Belgium', Decimal('51.2195'), Decimal('4.4024'), 'Antwerp, Belgium', 1857986], [5602, 'BE', 'BEL', 56, None, None, 'Brussels', 'Belgium', Decimal('50.8503'), Decimal('4.3517'), 'Brussels, Belgium', 1208542], [5603, 'BE', 'BEL', 56, None, None, 'East Flanders', 'Belgium', Decimal('51.0362'), Decimal('3.7373'), 'East Flanders, Belgium', 1515064], [5604, 'BE', 'BEL', 56, None, None, 'Flemish Brabant', 'Belgium', Decimal('50.9167'), Decimal('4.5833'), 'Flemish Brabant, Belgium', 1146175], [5605, 'BE', 'BEL', 56, None, None, 'Hainaut', 'Belgium', Decimal('50.5257'), Decimal('4.0621'), 'Hainaut, Belgium', 1344241], [5606, 'BE', 'BEL', 56, None, None, 'Liege', 'Belgium', Decimal('50.4496'), Decimal('5.8492'), 'Liege, Belgium', 1106992], [5607, 'BE', 'BEL', 56, None, None, 'Limburg', 'Belgium', Decimal('50.9739'), Decimal('5.342'), 'Limburg, Belgium', 874048], [5608, 'BE', 'BEL', 56, None, None, 'Luxembourg', 'Belgium', Decimal('50.0547'), Decimal('5.4677'), 'Luxembourg, Belgium', 284638], [5609, 'BE', 'BEL', 56, None, None, 'Namur', 'Belgium', Decimal('50.331'), Decimal('4.8221'), 'Namur, Belgium', 494325], [5610, 'BE', 'BEL', 56, None, None, 'Unknown', 'Belgium', None, None, 'Unknown, Belgium', None], [5611, 'BE', 'BEL', 56, None, None, 'Walloon Brabant', 'Belgium', Decimal('50.4'), Decimal('4.35'), 'Walloon Brabant, Belgium', 403599], [5612, 'BE', 'BEL', 56, None, None, 'West Flanders', 'Belgium', Decimal('51.0536'), Decimal('3.1458'), 'West Flanders, Belgium', 1195796], [84, 'BZ', 'BLZ', 84, None, None, None, 'Belize', Decimal('17.1899'), Decimal('-88.4976'), 'Belize', 397621], [204, 'BJ', 'BEN', 204, None, None, None, 'Benin', Decimal('9.3077'), Decimal('2.3158'), 'Benin', 12123198], [64, 'BT', 'BTN', 64, None, None, None, 'Bhutan', Decimal('27.5142'), Decimal('90.4336'), 'Bhutan', 771612], [68, 'BO', 'BOL', 68, None, None, None, 'Bolivia', Decimal('-16.2902'), Decimal('-63.5887'), 'Bolivia', 11673029], [70, 'BA', 'BIH', 70, None, None, None, 'Bosnia and Herzegovina', Decimal('43.9159'), Decimal('17.6791'), 'Bosnia and Herzegovina', 3280815], [72, 'BW', 'BWA', 72, None ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [[datetime.date(2020, 1, 22), 557, 30, 17, None], [datetime.date(2020, 1, 23), 655, 32, 18, Decimal('17.594254937163374')], [datetime.date(2020, 1, 24), 941, 39, 26, Decimal('43.66412213740458')], [datetime.date(2020, 1, 25), 1433, 42, 42, Decimal('52.28480340063763')], [datetime.date(2020, 1, 26), 2118, 56, 56, Decimal('47.801814375436145')], [datetime.date(2020, 1, 27), 2927, 65, 82, Decimal('38.196411709159584')], [datetime.date(2020, 1, 28), 5578, 108, 131, Decimal('90.57055005124701')], [datetime.date(2020, 1, 29), 6167, 127, 133, Decimal('10.559340265328075')], [datetime.date(2020, 1, 30), 8235, 145, 171, Decimal('33.533322523106854')], [datetime.date(2020, 1, 31), 9927, 225, 213, Decimal('20.546448087431692')], [datetime.date(2020, 2, 1), 12038, 287, 259, Decimal('21.2652362244384')], [datetime.date(2020, 2, 2), 16787, 476, 362, Decimal('39.45007476324971')], [datetime.date(2020, 2, 3), 19887, 627, 426, Decimal('18.466670637993683')], [datetime.date(2020, 2, 4), 23898, 857, 492, Decimal('20.16895459345301')], [datetime.date(2020, 2, 5), 27643, 1129, 564, Decimal('15.670767428236672')], [datetime.date(2020, 2, 6), 30803, 1492, 634, Decimal('11.431465470462685')], [datetime.date(2020, 2, 7), 34396, 2016, 719, Decimal('11.664448268025842')], [datetime.date(2020, 2, 8), 37130, 2616, 806, Decimal('7.948598674264449')], [datetime.date(2020, 2, 9), 40160, 3245, 906, Decimal('8.160517102073793')], [datetime.date(2020, 2, 10), 42769, 3947, 1013, Decimal('6.496513944223108')], [datetime.date(2020, 2, 11), 44811, 4684, 1113, Decimal('4.774486193270827')], [datetime.date(2020, 2, 12), 45229, 5151, 1118, Decimal('0.9328066769320033')], [datetime.date(2020, 2, 13), 60382, 6294, 1371, Decimal('33.50284109752592')], [datetime.date(2020, 2, 14), 66909, 8057, 1523, Decimal('10.809512768705906')], [datetime.date(2020, 2, 15), 69052, 9396, 1666, Decimal('3.2028576125782777')], [datetime.date(2020, 2, 16), 71235, 10866, 1770, Decimal('3.161385622429473')], [datetime.date(2020, 2, 17), 73270, 12583, 1868, Decimal('2.8567417701972344')], [datetime.date(2020, 2, 18), 75152, 14352, 2008, Decimal('2.568581957144807')], [datetime.date(2020, 2, 19), 75652, 16121, 2123, Decimal('0.665318288269108')], [datetime.date(2020, 2, 20), 76212, 18179, 2248, Decimal('0.7402315867392799')], [datetime.date(2020, 2, 21), 76841, 18892, 2252, Decimal('0.82532934446019')], [datetime.date(2020, 2, 22), 78602, 22889, 2459, Decimal('2.291745292226806')], [datetime.date(2020, 2, 23), 78982, 23394, 2470, Decimal('0.4834482583140378')], [datetime.date(2020, 2, 24), 79546, 25227, 2630, Decimal('0.7140867539439366')], [datetime.date(2020, 2, 25), 80399, 27905, 2710, Decimal('1.0723355039851157')], [datetime.date(2020, 2, 26), 81376, 30386, 2771, Decimal('1.215189243647309')], [datetime.date(2020, 2, 27), 82736, 33278, 2814, Decimal('1.6712544239087694')], [datetime.date(2020, 2, 28), 84122, 36710, 2873, Decimal('1.675207890156643')], [datetime.date(2020, 2, 29), 86013, 39781, 2942, Decimal('2.247925631820451')], [datetime.date(2020, 3, 1), 88394, 42717, 2996, Decimal('2.768186204410961')], [datetime.date(2020, 3, 2), 90377, 45601, 3085, Decimal('2.2433649342715567')], [datetime.date(2020, 3, 3), 92971, 48227, 3160, Decimal('2.870199276364562')], [datetime.date(2020, 3, 4), 95279, 51169, 3255, Decimal('2.4824945413085797')], [datetime.date(2020, 3, 5), 98090, 53795, 3349, Decimal('2.9502828535144157')], [datetime.date(2020, 3, 6), 102003, 55863, 3460, Decimal('3.9891935977163833')], [datetime.date(2020, 3, 7), 106098, 58357, 3564, Decimal('4.014587806240993')], [datetime.date(2020, 3, 8), 110047, 60694, 3803, Decimal('3.7220305755056646')], [datetime.date(2020, 3, 9), 114219, 62493, 3993, Decimal('3.7911074359137458')], [datetime.date(2020, 3, 10), 119041, 64400, 4267, Decimal('4.221714425796058')], [datetime.date(2020, 3, 11), 126702, 66998, 4611, Decimal('6.43559781923875')], [datetime.date(2020, 3, 12), 132492, 68321, 4917, Decimal('4.569777904058342')], [datetime.date( ...
